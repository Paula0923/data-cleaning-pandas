# %%
import pandas as pd

# %%
# pip install xlrd

# %%
df = pd.read_excel(r"C:\Users\paula\01_Ironhack\projects\quest shark attacks\GSAF5.xls")

# %%
df.head(2)
# Out:
#           Date    Year        Type    Country       State            Location  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA  Queensland       Bargara Beach
# 1  04 Mar 2024  2024.0  Unprovoked        USA      Hawaii  Old Man's, Waikiki
#
#    Activity            Name Sex  Age  ...        Species   \
# 0  Swimming  Brooklyn Sauer   F   13  ...     Tiger shark
# 1   Surfing   Matthew White   M  NaN  ...  Tiger shark 8'
#
#                   Source  pdf href formula href Case Number Case Number.1  \
# 0  Yahoo News, 3/15/2024  NaN          NaN  NaN         NaN           NaN
# 1      Surfer, 3/6/2024F  NaN          NaN  NaN         NaN           NaN
#
#   original order Unnamed: 21 Unnamed: 22
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# """
#
# """

# %%
df.sample(10)
# Out:
#                       Date    Year        Type       Country  \
# 4961           28-Jul-1954  1954.0  Unprovoked     SINGAPORE
# 1306  Reported 21-Mar-2013  2013.0  Unprovoked        BELIZE
# 1658           04-Feb-2010  2010.0     Invalid          GUAM
# 697            15-Sep-2017  2017.0         NaN         SAMOA
# 3              25 Feb-2024  2024.0  Unprovoked     AUSTRALIA
# 92             23-Apr-2023  2023.0  Unprovoked           USA
# 6738  Reported 15-Aug-1826  1826.0  Unprovoked       ENGLAND
# 2794           11-Jul-1998  1998.0  Unprovoked  SOUTH AFRICA
# 1280           16-Jun-2013  2013.0  Unprovoked  SOUTH AFRICA
# 2407           04-Apr-2003  2003.0  Unprovoked           USA
#
#                       State                           Location  \
# 4961                    NaN                   Singapore Harbor
# 1306                    NaN                                NaN
# 1658                 Merizo                        Achang Reef
# ...

# %%
df.shape
# Out:
# (6969, 23)

# %%
df.tail(50)
# Out:
#                                                    Date  Year        Type  \
# 6919                                        Before 1927   0.0  Unprovoked
# 6920                                Between 1918 & 1939   0.0  Unprovoked
# 6921                                            No date   0.0  Unprovoked
# 6922                                            No date   0.0  Unprovoked
# 6923                                            No date   0.0  Unprovoked
# 6924                                         1920 -1923   0.0  Unprovoked
# 6925                                        Before 1921   0.0  Unprovoked
# 6926                                        Before 1911   0.0  Unprovoked
# 6927                                        Before 1921   0.0  Unprovoked
# 6928                                        Before 1921   0.0  Unprovoked
# 6929                                        Before 1917   0.0  Unprovoked
# 6930                                 Before 17-Jul-1916   0.0  Unprovoked
# ...

# %%
df.Injury
# Out:
# 0       Minor injuries to back, abdomen and legs
# 1                 No injury, shark bit surfboard
# 2                       Lacerations to left foot
# 3                                     Leg bitten
# 4                 Calf of lower left leg injured
#                           ...
# 6964                                         NaN
# 6965                                         NaN
# 6966                                         NaN
# 6967                                         NaN
# 6968                                         NaN
# Name: Injury, Length: 6969, dtype: object
