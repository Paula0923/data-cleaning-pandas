# %%
import pandas as pd

# %%
# pip install xlrd

# %%
df = pd.read_excel(r"C:\Users\paula\01_Ironhack\projects\quest shark attacks\coral-reefs_shark-attack\GSAF5.xls")

# %%
df.shape
# Out:
# (6969, 23)

# %%
df.head(20)
# Out:
#             Date    Year          Type       Country                   State  \
# 0    15 Mar 2024  2024.0    Unprovoked     AUSTRALIA              Queensland
# 1    04 Mar 2024  2024.0    Unprovoked           USA                  Hawaii
# 2    02 Mar-2024  2024.0    Unprovoked           USA                  Hawaii
# 3    25 Feb-2024  2024.0    Unprovoked     AUSTRALIA       Western Australia
# 4    14 Feb-2024  2024.0    Unprovoked         INDIA             Maharashtra
# 5    04-Feb-2024  2024.0      Provoked      TRINIDAD                     NaN
# 6    29 Jan-2024  2024.0    Unprovoked     AUSTRALIA        New  South Wales
# 7    15 Jan-2024  2024.0    Unprovoked       BAHAMAS         Paradise Island
# 8    09-Jan-2024  2024.0    Unprovoked     AUSTRALIA         South Australia
# 9    05-Jan-2024  2024.0      Provoked  SOUTH AFRICA   Eastern Cape Province
# 10   30 Dec-2023  2023.0    Unprovoked           USA                  Hawaii
# ...

# %%
df.sample(20)
# Out:
#                                    Date    Year          Type  \
# 3161                        08-Jul-1992  1992.0    Unprovoked
# 5069  Between 01-Aug-1951 & 08-Aug-1951  1951.0    Unprovoked
# 1906                         2008.01.30  2008.0      Provoked
# 4064                        19-Aug-1969  1969.0      Provoked
# 5461                        13-Nov-1937  1937.0  Sea Disaster
# 6423                               1883  1883.0    Unprovoked
# 438                         30-Nov-2019  2019.0    Unprovoked
# 4621                        30-Apr-1960  1960.0    Unprovoked
# 4073                        26-Dec-1968  1968.0      Provoked
# 1125                        27-Aug-2014  2014.0    Unprovoked
# 2931                        09-Feb-1996  1996.0    Unprovoked
# 2779               Reported 16-Sep-1998  1998.0    Unprovoked
# 5075               Reported 09-May-1951  1951.0      Provoked
# 3272                        12-Nov-1989  1989.0       Invalid
# ...

# %%
df.tail(26)
# Out:
#            Date  Year        Type             Country             State  \
# 6943  1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
# 6944        NaN   NaN         NaN                 NaN               NaN
# 6945        NaN   NaN         NaN                 NaN               NaN
# 6946        NaN   NaN         NaN                 NaN               NaN
# 6947        NaN   NaN         NaN                 NaN               NaN
# 6948        NaN   NaN         NaN                 NaN               NaN
# 6949        NaN   NaN         NaN                 NaN               NaN
# 6950        NaN   NaN         NaN                 NaN               NaN
# 6951        NaN   NaN         NaN                 NaN               NaN
# 6952        NaN   NaN         NaN                 NaN               NaN
# 6953        NaN   NaN         NaN                 NaN               NaN
# 6954        NaN   NaN         NaN                 NaN               NaN
# ...

# %%
df.isna().sum()
# Out:
# Date                25
# Year                27
# Type                43
# Country             75
# State              507
# Location           590
# Activity           611
# Name               245
# Sex                604
# Age               3019
# Injury              60
# Unnamed: 11        587
# Time              3551
# Species           3157
# Source              44
# pdf                170
# href formula       150
# href               173
# Case Number        171
# Case Number.1      172
# original order     170
# Unnamed: 21       6968
# Unnamed: 22       6967
# dtype: int64

# %%
df["Unnamed: 11"].sample(20)
# Out:
# 3197        NaN
# 945           N
# 659           N
# 1327          N
# 2756        NaN
# 4636          N
# 6470          Y
# 4167          N
# 1607          N
# 2687          N
# 5200          Y
# 6805    UNKNOWN
# 4696        NaN
# 1215          N
# 3173          N
# 5148          Y
# 1541          N
# 4985          N
# 5971          Y
# 3825          N
# Name: Unnamed: 11, dtype: object

# %%
df.Injury
# Out:
# 0       Minor injuries to back, abdomen and legs
# 1                 No injury, shark bit surfboard
# 2                       Lacerations to left foot
# 3                                     Leg bitten
# 4                 Calf of lower left leg injured
#                           ...
# 6964                                         NaN
# 6965                                         NaN
# 6966                                         NaN
# 6967                                         NaN
# 6968                                         NaN
# Name: Injury, Length: 6969, dtype: object

# %%
df["Unnamed: 22"].notnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6964    False
# 6965    False
# 6966    False
# 6967    False
# 6968    False
# Name: Unnamed: 22, Length: 6969, dtype: bool

# %%
df[df["Unnamed: 22"] != "NaN"]
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# ...

# %%
df.eq(" ").sum() # 1 empty space
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          1
# Name              0
# Sex               0
# Age               2
# Injury            1
# Unnamed: 11       0
# Time              2
# Species           7
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("  ").sum() # 2 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               1
# Injury            0
# Unnamed: 11       0
# Time              1
# Species           1
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("   ").sum() # 3 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          1
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              1
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("    ").sum() # 4 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("     ").sum() # 5 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("      ").sum() # 6 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("       ").sum() # 7 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("        ").sum() # 8 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64

# %%
df.eq("         ").sum() # 9 empty spaces
# Out:
# Date              0
# Year              0
# Type              0
# Country           0
# State             0
# Location          0
# Activity          0
# Name              0
# Sex               0
# Age               0
# Injury            0
# Unnamed: 11       0
# Time              0
# Species           0
# Source            0
# pdf               0
# href formula      0
# href              0
# Case Number       0
# Case Number.1     0
# original order    0
# Unnamed: 21       0
# Unnamed: 22       0
# dtype: int64
